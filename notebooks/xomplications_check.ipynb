# %%
import pandas as pd

df = pd.read_csv("../data/synthetic_diabetes_registry_700000.csv")

print("Retinopathy")
print(df["Retinopathy"].value_counts())

print("\nNephropathy")
print(df["Nephropathy"].value_counts())

print("\nNeuropathy")
print(df["Neuropathy"].value_counts())

print("\nCAD")
print(df["CAD"].value_counts())

print("\nStroke")
print(df["Stroke"].value_counts())
# Out:
# Retinopathy
# Retinopathy
# Mild        140149
# Moderate    104837
# Severe       34784
# Name: count, dtype: int64
#
# Nephropathy
# Nephropathy
# Mild        140088
# Moderate    126008
# Severe       49206
# Name: count, dtype: int64
#
# Neuropathy
# Neuropathy
# Mild        175253
# Moderate    126077
# Severe       48984
# Name: count, dtype: int64
#
# CAD
# CAD
# Yes    350192
# No     349808
# Name: count, dtype: int64
#
# Stroke
# Stroke
# Yes    350305
# No     349695
# Name: count, dtype: int64
